# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/camenduru/so-vits-svc-colab/blob/main/test.ipynb)

# %%
# %cd /content
# !git clone https://github.com/camenduru/so-vits-svc-fork
# %cd /content/so-vits-svc-fork
# %pip install .

# !apt -y install -qq aria2
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/so-vits-svc-test/resolve/main/test_song.wav -d /content -o test_song.wav

# %cd /content

from IPython.display import Audio

# %%
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/Itoifi/so-vits-svc-acg-models/resolve/main/44k-V4.0-luna/G_289600.pth -d /content/models/luna -o G_289600.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/Itoifi/so-vits-svc-acg-models/raw/main/44k-V4.0-luna/config.json -d /content/models/luna -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/TachibanaKimika/so-vits-svc-4.0-models/resolve/main/riri/G_riri_220.pth -d /content/models/riri -o G_riri_220.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/TachibanaKimika/so-vits-svc-4.0-models/resolve/main/riri/config.json -d /content/models/riri -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/resolve/main/21Savage/G_100000.pth -d /content/models/21Savage -o G_100000.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/raw/main/21Savage/config.json -d /content/models/21Savage -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/resolve/main/2Pac/G_50067.pth -d /content/models/2Pac -o G_50067.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/raw/main/2Pac/config.json -d /content/models/2Pac -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/resolve/main/AliciaKeys/G_6018.pth -d /content/models/AliciaKeys -o G_6018.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/raw/main/AliciaKeys/config.json -d /content/models/AliciaKeys -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/resolve/main/AndrewTate/G_40900.pth -d /content/models/AndrewTate -o G_40900.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/raw/main/AndrewTate/config.json -d /content/models/AndrewTate -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/resolve/main/Ariana/G_53600.pth -d /content/models/Ariana -o G_53600.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/raw/main/Ariana/config.json -d /content/models/Ariana -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/resolve/main/AyeshaErotica/G_100000.pth -d /content/models/AyeshaErotica -o G_100000.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/raw/main/AyeshaErotica/config.json -d /content/models/AyeshaErotica -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/resolve/main/BLACKPINK_Jennie/G_65600.pth -d /content/models/BLACKPINK_Jennie -o G_65600.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/raw/main/BLACKPINK_Jennie/config.json -d /content/models/BLACKPINK_Jennie -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/resolve/main/BLACKPINK_Jisoo/G_113000.pth -d /content/models/BLACKPINK_Jisoo -o G_113000.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/raw/main/BLACKPINK_Jisoo/config.json -d /content/models/BLACKPINK_Jisoo -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/resolve/main/BLACKPINK_Lisa/G_2400.pth -d /content/models/BLACKPINK_Lisa -o G_2400.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/raw/main/BLACKPINK_Lisa/config.json -d /content/models/BLACKPINK_Lisa -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/resolve/main/BLACKPINK_Rose/G_2400.pth -d /content/models/BLACKPINK_Rose -o G_2400.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/raw/main/BLACKPINK_Rose/config.json -d /content/models/BLACKPINK_Rose -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/resolve/main/BROCKHAMPTON_Ameer/G_15000.pth -d /content/models/BROCKHAMPTON_Ameer -o G_15000.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/raw/main/BROCKHAMPTON_Ameer/config.json -d /content/models/BROCKHAMPTON_Ameer -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/resolve/main/BROCKHAMPTON_Joba/G_15000.pth -d /content/models/BROCKHAMPTON_Joba -o G_15000.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/raw/main/BROCKHAMPTON_Joba/config.json -d /content/models/BROCKHAMPTON_Joba -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/resolve/main/BabyKeem/G_191000.pth -d /content/models/BabyKeem -o G_191000.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/raw/main/BabyKeem/config.json -d /content/models/BabyKeem -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/resolve/main/BartSimpson/G_22000.pth -d /content/models/BartSimpson -o G_22000.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/raw/main/BartSimpson/config.json -d /content/models/BartSimpson -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/resolve/main/Beatles_GeorgeHarrison/G_101.pth -d /content/models/Beatles_GeorgeHarrison -o G_101.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/raw/main/Beatles_GeorgeHarrison/config.json -d /content/models/Beatles_GeorgeHarrison -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/resolve/main/BillieEilish/G_8000.pth -d /content/models/BillieEilish -o G_8000.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/raw/main/BillieEilish/config.json -d /content/models/BillieEilish -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/resolve/main/BillieEilishNew/G_1600.pth -d /content/models/BillieEilishNew -o G_1600.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/raw/main/BillieEilishNew/config.json -d /content/models/BillieEilishNew -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/resolve/main/BrendonUrie/G_49600.pth -d /content/models/BrendonUrie -o G_49600.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/raw/main/BrendonUrie/config.json -d /content/models/BrendonUrie -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/resolve/main/BrunoMars/G_24025.pth -d /content/models/BrunoMars -o G_24025.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/raw/main/BrunoMars/config.json -d /content/models/BrunoMars -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/resolve/main/BrunoMars124K/G_124930.pth -d /content/models/BrunoMars124K -o G_124930.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/raw/main/BrunoMars124K/config.json -d /content/models/BrunoMars124K -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/resolve/main/ChesterBennington/G_79200.pth -d /content/models/ChesterBennington -o G_79200.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/raw/main/ChesterBennington/config.json -d /content/models/ChesterBennington -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/resolve/main/ChiefKeef/G_100000.pth -d /content/models/ChiefKeef -o G_100000.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/raw/main/ChiefKeef/config.json -d /content/models/ChiefKeef -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/resolve/main/ChrisCornell/G_7400.pth -d /content/models/ChrisCornell -o G_7400.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/raw/main/ChrisCornell/config.json -d /content/models/ChrisCornell -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/resolve/main/CupcaKKe/G_15000.pth -d /content/models/CupcaKKe -o G_15000.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/raw/main/CupcaKKe/config.json -d /content/models/CupcaKKe -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/resolve/main/DavidBowie/G_7200.pth -d /content/models/DavidBowie -o G_7200.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/raw/main/DavidBowie/config.json -d /content/models/DavidBowie -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/resolve/main/DojaCat/G_163200.pth -d /content/models/DojaCat -o G_163200.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/raw/main/DojaCat/config.json -d /content/models/DojaCat -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/resolve/main/DonToliver/G_75200.pth -d /content/models/DonToliver -o G_75200.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/raw/main/DonToliver/config.json -d /content/models/DonToliver -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/resolve/main/Drake/G_106000.pth -d /content/models/Drake -o G_106000.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/raw/main/Drake/config.json -d /content/models/Drake -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/resolve/main/DuaLipa/G_36000.pth -d /content/models/DuaLipa -o G_36000.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/raw/main/DuaLipa/config.json -d /content/models/DuaLipa -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/resolve/main/Eminem/G_86400.pth -d /content/models/Eminem -o G_86400.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/raw/main/Eminem/config.json -d /content/models/Eminem -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/resolve/main/EminemSlimShadyEra/G_203200.pth -d /content/models/EminemSlimShadyEra -o G_203200.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/raw/main/EminemSlimShadyEra/config.json -d /content/models/EminemSlimShadyEra -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/resolve/main/EricCartman/G_10200.pth -d /content/models/EricCartman -o G_10200.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/raw/main/EricCartman/config.json -d /content/models/EricCartman -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/resolve/main/FrankOcean/G_25000.pth -d /content/models/FrankOcean -o G_25000.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/raw/main/FrankOcean/config.json -d /content/models/FrankOcean -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/resolve/main/FreddieMercury/G_300000.pth -d /content/models/FreddieMercury -o G_300000.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/raw/main/FreddieMercury/config.json -d /content/models/FreddieMercury -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/resolve/main/GawrGura/G_30400.pth -d /content/models/GawrGura -o G_30400.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/raw/main/GawrGura/config.json -d /content/models/GawrGura -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/resolve/main/HarryStyles/G_56000.pth -d /content/models/HarryStyles -o G_56000.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/raw/main/HarryStyles/config.json -d /content/models/HarryStyles -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/resolve/main/HollywoodUndead_CharlieSceneRapping/G_14000.pth -d /content/models/HollywoodUndead_CharlieSceneRapping -o G_14000.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/raw/main/HollywoodUndead_CharlieSceneRapping/config.json -d /content/models/HollywoodUndead_CharlieSceneRapping -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/resolve/main/IceSpice/G_4000.pth -d /content/models/IceSpice -o G_4000.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/raw/main/IceSpice/config.json -d /content/models/IceSpice -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/resolve/main/JCole/G_100000.pth -d /content/models/JCole -o G_100000.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/raw/main/JCole/config.json -d /content/models/JCole -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/resolve/main/JamesHetfield/G_49600.pth -d /content/models/JamesHetfield -o G_49600.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/raw/main/JamesHetfield/config.json -d /content/models/JamesHetfield -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/resolve/main/JayZ/G_54400.pth -d /content/models/JayZ -o G_54400.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/raw/main/JayZ/config.json -d /content/models/JayZ -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/resolve/main/JuiceWRLD/G_163200.pth -d /content/models/JuiceWRLD -o G_163200.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/raw/main/JuiceWRLD/config.json -d /content/models/JuiceWRLD -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/resolve/main/JuiceWRLDAgressive/G_28000.pth -d /content/models/JuiceWRLDAgressive -o G_28000.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/raw/main/JuiceWRLDAgressive/config.json -d /content/models/JuiceWRLDAgressive -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/resolve/main/JustinBieber/G_67200.pth -d /content/models/JustinBieber -o G_67200.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/raw/main/JustinBieber/config.json -d /content/models/JustinBieber -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/resolve/main/Kanye/G_199200.pth -d /content/models/Kanye -o G_199200.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/raw/main/Kanye/config.json -d /content/models/Kanye -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/resolve/main/KatyPerry/G_28000.pth -d /content/models/KatyPerry -o G_28000.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/raw/main/KatyPerry/config.json -d /content/models/KatyPerry -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/resolve/main/KendrickLamar/G_1002000.pth -d /content/models/KendrickLamar -o G_1002000.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/raw/main/KendrickLamar/config.json -d /content/models/KendrickLamar -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/resolve/main/KurtCobain/G_138600.pth -d /content/models/KurtCobain -o G_138600.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/raw/main/KurtCobain/config.json -d /content/models/KurtCobain -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/resolve/main/LadyGaga/G_14400.pth -d /content/models/LadyGaga -o G_14400.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/raw/main/LadyGaga/config.json -d /content/models/LadyGaga -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/resolve/main/LanaDelRey/G_100000.pth -d /content/models/LanaDelRey -o G_100000.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/raw/main/LanaDelRey/config.json -d /content/models/LanaDelRey -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/resolve/main/LiamGallagher/G_18400.pth -d /content/models/LiamGallagher -o G_18400.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/raw/main/LiamGallagher/config.json -d /content/models/LiamGallagher -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/resolve/main/LilNasX/G_26000.pth -d /content/models/LilNasX -o G_26000.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/raw/main/LilNasX/config.json -d /content/models/LilNasX -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/resolve/main/LilTecca/G_100200.pth -d /content/models/LilTecca -o G_100200.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/raw/main/LilTecca/config.json -d /content/models/LilTecca -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/resolve/main/LilUziVert/G_237600.pth -d /content/models/LilUziVert -o G_237600.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/raw/main/LilUziVert/config.json -d /content/models/LilUziVert -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/resolve/main/LisaSimpson/G_22000.pth -d /content/models/LisaSimpson -o G_22000.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/raw/main/LisaSimpson/config.json -d /content/models/LisaSimpson -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/resolve/main/MF_DOOM/G_45000.pth -d /content/models/MF_DOOM -o G_45000.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/raw/main/MF_DOOM/config.json -d /content/models/MF_DOOM -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/resolve/main/MJAI_83k/G_83000.pth -d /content/models/MJAI_83k -o G_83000.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/raw/main/MJAI_83k/config.json -d /content/models/MJAI_83k -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/resolve/main/MelanieMartinez/G_40000.pth -d /content/models/MelanieMartinez -o G_40000.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/raw/main/MelanieMartinez/config.json -d /content/models/MelanieMartinez -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/resolve/main/MelanieMartinez72K/G_72000.pth -d /content/models/MelanieMartinez72K -o G_72000.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/raw/main/MelanieMartinez72K/config.json -d /content/models/MelanieMartinez72K -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/resolve/main/MichaelJackson/G_83000.pth -d /content/models/MichaelJackson -o G_83000.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/raw/main/MichaelJackson/config.json -d /content/models/MichaelJackson -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/resolve/main/NickiMinaj/G_7000.pth -d /content/models/NickiMinaj -o G_7000.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/raw/main/NickiMinaj/config.json -d /content/models/NickiMinaj -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/resolve/main/NipseyHussle/G_100000.pth -d /content/models/NipseyHussle -o G_100000.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/raw/main/NipseyHussle/config.json -d /content/models/NipseyHussle -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/resolve/main/NottiOsama/G_32000.pth -d /content/models/NottiOsama -o G_32000.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/raw/main/NottiOsama/config.json -d /content/models/NottiOsama -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/resolve/main/NottiOsama60K/G_59200.pth -d /content/models/NottiOsama60K -o G_59200.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/raw/main/NottiOsama60K/config.json -d /content/models/NottiOsama60K -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/resolve/main/PaulMcCartney/G_208800.pth -d /content/models/PaulMcCartney -o G_208800.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/raw/main/PaulMcCartney/config.json -d /content/models/PaulMcCartney -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/resolve/main/PlayboiCarti/G_45000.pth -d /content/models/PlayboiCarti -o G_45000.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/raw/main/PlayboiCarti/config.json -d /content/models/PlayboiCarti -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/resolve/main/PopSmoke/G_36800.pth -d /content/models/PopSmoke -o G_36800.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/raw/main/PopSmoke/config.json -d /content/models/PopSmoke -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/resolve/main/Rihanna/G_200000.pth -d /content/models/Rihanna -o G_200000.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/raw/main/Rihanna/config.json -d /content/models/Rihanna -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/resolve/main/RochyRD/G_9000.pth -d /content/models/RochyRD -o G_9000.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/raw/main/RochyRD/config.json -d /content/models/RochyRD -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/resolve/main/Rosalia/G_35000.pth -d /content/models/Rosalia -o G_35000.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/raw/main/Rosalia/config.json -d /content/models/Rosalia -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/resolve/main/SamuelLJackson/G_30000.pth -d /content/models/SamuelLJackson -o G_30000.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/raw/main/SamuelLJackson/config.json -d /content/models/SamuelLJackson -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/resolve/main/StevieWonder/G_31000.pth -d /content/models/StevieWonder -o G_31000.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/raw/main/StevieWonder/config.json -d /content/models/StevieWonder -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/resolve/main/SwaeLee/G_231200.pth -d /content/models/SwaeLee -o G_231200.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/raw/main/SwaeLee/config.json -d /content/models/SwaeLee -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/resolve/main/TXT_Soobin/G_46400.pth -d /content/models/TXT_Soobin -o G_46400.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/raw/main/TXT_Soobin/config.json -d /content/models/TXT_Soobin -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/resolve/main/TaylorSwift/G_106400.pth -d /content/models/TaylorSwift -o G_106400.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/raw/main/TaylorSwift/config.json -d /content/models/TaylorSwift -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/resolve/main/TaylorSwift101K/G_3300.pth -d /content/models/TaylorSwift101K -o G_3300.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/raw/main/TaylorSwift101K/config.json -d /content/models/TaylorSwift101K -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/resolve/main/TheKidLaroi/G_171200.pth -d /content/models/TheKidLaroi -o G_171200.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/raw/main/TheKidLaroi/config.json -d /content/models/TheKidLaroi -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/resolve/main/TheKidLaroi342K/G_342160.pth -d /content/models/TheKidLaroi342K -o G_342160.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/raw/main/TheKidLaroi342K/config.json -d /content/models/TheKidLaroi342K -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/resolve/main/TheNotoriousBIG/G_112800.pth -d /content/models/TheNotoriousBIG -o G_112800.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/raw/main/TheNotoriousBIG/config.json -d /content/models/TheNotoriousBIG -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/resolve/main/TheWeeknd/G_94400.pth -d /content/models/TheWeeknd -o G_94400.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/raw/main/TheWeeknd/config.json -d /content/models/TheWeeknd -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/resolve/main/TheWeeknd60K/G_60000.pth -d /content/models/TheWeeknd60K -o G_60000.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/raw/main/TheWeeknd60K/config.json -d /content/models/TheWeeknd60K -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/resolve/main/Travis/G_77000.pth -d /content/models/Travis -o G_77000.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/raw/main/Travis/config.json -d /content/models/Travis -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/resolve/main/TylerTheCreator/G_104000.pth -d /content/models/TylerTheCreator -o G_104000.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/raw/main/TylerTheCreator/config.json -d /content/models/TylerTheCreator -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/resolve/main/XXXTentacion165K/G_195000.pth -d /content/models/XXXTentacion165K -o G_195000.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/raw/main/XXXTentacion165K/config.json -d /content/models/XXXTentacion165K -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/resolve/main/Yeat/G_60000.pth -d /content/models/Yeat -o G_60000.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/raw/main/Yeat/config.json -d /content/models/Yeat -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/resolve/main/YoungThug153K/G_153000.pth -d /content/models/YoungThug153K -o G_153000.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/raw/main/YoungThug153K/config.json -d /content/models/YoungThug153K -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/resolve/main/YoungThug279K/G_279200.pth -d /content/models/YoungThug279K -o G_279200.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/raw/main/YoungThug279K/config.json -d /content/models/YoungThug279K -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/resolve/main/drake05/G_106000.pth -d /content/models/drake05 -o G_106000.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/raw/main/drake05/config.json -d /content/models/drake05 -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/resolve/main/juice/G_163200.pth -d /content/models/juice -o G_163200.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/raw/main/juice/config.json -d /content/models/juice -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/resolve/main/kanye/G_199200.pth -d /content/models/kanye -o G_199200.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/raw/main/kanye/config.json -d /content/models/kanye -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/resolve/main/paul/G_208800.pth -d /content/models/paul -o G_208800.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/raw/main/paul/config.json -d /content/models/paul -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/resolve/main/rihanna200k/G_200000.pth -d /content/models/rihanna200k -o G_200000.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/raw/main/rihanna200k/config.json -d /content/models/rihanna200k -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/resolve/main/travis77k/G_77000.pth -d /content/models/travis77k -o G_77000.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/raw/main/travis77k/config.json -d /content/models/travis77k -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/resolve/main/weeknd/G_94400.pth -d /content/models/weeknd -o G_94400.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/raw/main/weeknd/config.json -d /content/models/weeknd -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/resolve/main/xQc/G_25000.pth -d /content/models/xQc -o G_25000.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://lilpotat: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@huggingface.co/lilpotat/singers/raw/main/xQc/config.json -d /content/models/xQc -o config.json

# %%
# !pip install -q yt_dlp pydub

# %%
from yt_dlp import YoutubeDL
with YoutubeDL({'overwrites':True, 'format':'bestaudio[ext=m4a]', 'outtmpl':'/content/audio.m4a'}) as ydl:
    ydl.download("https://www.youtube.com/watch?v=Uxc6tzXis8Y")

import pydub

audio_segment = pydub.AudioSegment.from_file("audio.m4a")
audio_segment.export("audio.wav", format="wav")

# %%
# !svc infer /content/audio.wav -o /content/test_song_out2.wav -c /content/models/TaylorSwift/config.json -m /content/models/TaylorSwift/G_106400.pth -fm crepe
Audio(f"/content/test_song_out2.wav")

# %%
# !svc infer /content/audio.wav -o /content/test_song_out1.wav -c /content/models/TaylorSwift101K/config.json -m /content/models/TaylorSwift101K/G_3300.pth -fm crepe
Audio(f"/content/test_song_out1.wav")

# %%
# !pip install -q spleeter yt_dlp
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M  https://github.com/deezer/spleeter/raw/master/audio_example.mp3 -d /content -o audio.mp3

# %%
Audio('/content/audio.mp3')

# %%
# !spleeter separate --help
# !spleeter separate -o /content/output1/ audio.mp3

# %%
Audio('/content/output1/audio/vocals.wav')

# %%
Audio('/content/output1/audio/accompaniment.wav')

# %%
from yt_dlp import YoutubeDL
with YoutubeDL({'overwrites':True, 'format':'bestaudio[ext=m4a]', 'outtmpl':'/content/audio.m4a'}) as ydl:
    ydl.download("https://www.youtube.com/watch?v=F7nQ0VUAOXg")

# %%
Audio('/content/audio.m4a')

# %%
# !spleeter separate --help
# !spleeter separate -o /content/output2/ audio.m4a

# %%
Audio('/content/output2/audio/vocals.wav')

# %%
Audio('/content/output2/audio/accompaniment.wav')

# %%
# "-o", "--output-path", help="path to output dir"
# "-s", "--speaker", help="speaker name"
# "-m", "--model-path", help="path to model"
# "-c", "--config-path", help="path to config"
# "-k", "--cluster-model-path", help="path to cluster model"
# "-t", "--transpose", default=0, help="transpose"
# "-db", "--db-thresh", default=-40, help="threshold (DB) (RELATIVE)"
# "-fm", "--f0-method", default="dio", ["crepe", "crepe-tiny", "parselmouth", "dio", "harvest"], help="f0 prediction method"
# "-a/-na", "--auto-predict-f0/--no-auto-predict-f0", default=False, help="auto predict f0"
# "-r", "--cluster-infer-ratio", default=0, help="cluster infer ratio"
# "-n", "--noise-scale", default=0.4, help="noise scale"
# "-p", "--pad-seconds", default=0.5, help="pad seconds"
# "-d", "--device", help="device"
# "-ch", "--chunk-seconds", default=0.5, help="chunk seconds")
# "-ab/-nab","--absolute-thresh/--no-absolute-thresh", default=False, help="absolute thresh",

# %%
# !svc infer /content/output1/audio/vocals.wav -o /content/vocals_out1.wav -c /content/models/luna/config.json -m /content/models/luna/G_289600.pth -fm crepe
Audio(f"/content/vocals_out1.wav")

# %%
# !svc infer /content/output2/audio/vocals.wav -o /content/vocals_out2.wav -c /content/models/luna/config.json -m /content/models/luna/G_289600.pth -fm crepe
Audio(f"/content/vocals_out2.wav")

# %%
# !svc infer /content/test_song.wav -o /content/test_song_out2.wav -c /content/models/luna/config.json -m /content/models/luna/G_289600.pth -fm crepe
Audio(f"/content/test_song_out2.wav")

# %%
# !svc infer /content/test_song.wav -o /content/test_song_out1.wav -c /content/models/riri/config.json -m /content/models/riri/G_riri_220.pth -fm crepe
Audio(f"/content/test_song_out1.wav")
